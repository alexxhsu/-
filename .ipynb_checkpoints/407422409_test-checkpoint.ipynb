# %%
import pandas
from pandas import DataFrame
import jaydebeapi

# %% [markdown]
# <h3>pip install pyArango</h3>

# %%
from pyArango.connection import*
from pyArango.query import*
import pyArango.validation as VAL

# %%
data=pandas.read_csv("C:\\Users\\user\\anaconda3\\Projects\\data\\reddit_vm.csv",encoding='utf-8')
data
# Out:
#                                                   title  score       id  \
# 0     Health Canada approves AstraZeneca COVID-19 va...      7   lt74vw
# 1     COVID-19 in Canada: 'Vaccination passports' a ...      2   lsh0ij
# 2     Coronavirus variants could fuel Canada's third...      6   lohlle
# 3     Canadian government to extend COVID-19 emergen...      1   lnptv8
# 4     Canada: Pfizer is 'extremely committed' to mee...      6   lkslm6
# ...                                                 ...    ...      ...
# 1592                                            Comment      1  elrrt5l
# 1593                                            Comment      1  elrqfk3
# 1594                                            Comment      1  elrph9m
# 1595                                            Comment      1  elroxqn
# 1596                                            Comment      1  elro7rb
#
#                                                     url  comms_num  \
# 0     https://www.canadaforums.ca/2021/02/health-can...          0
# 1     https://www.canadaforums.ca/2021/02/covid-19-i...          1
# 2     https://www.canadaforums.ca/2021/02/coronaviru...          0
# 3     https://www.canadaforums.ca/2021/02/canadian-g...          0
# 4     https://www.canadaforums.ca/2021/02/canada-pfi...          0
# ...                                                 ...        ...
# 1592                                                NaN          0
# 1593                                                NaN          0
# 1594                                                NaN          0
# 1595                                                NaN          0
# 1596                                                NaN          0
#
#            created                                               body  \
# 0     1.614400e+09                                                NaN
# 1     1.614316e+09                                                NaN
# 2     1.613887e+09                                                NaN
# 3     1.613796e+09                                                NaN
# 4     1.613468e+09                                                NaN
# ...            ...                                                ...
# 1592  1.556221e+09  How long does it take ethyl mercury to metabol...
# 1593  1.556220e+09  > Why is it sounding like I'm scraping the bot...
# 1594  1.556220e+09  Why is it sounding like I'm scraping the botto...
# 1595  1.556219e+09  Is that what the study said? Did you read the ...
# 1596  1.556219e+09  >So on the one hand you say a paper is needed\...
#
#                 timestamp
# 0     2021-02-27 06:33:45
# 1     2021-02-26 07:11:07
# 2     2021-02-21 07:50:08
# 3     2021-02-20 06:35:13
# 4     2021-02-16 11:36:28
# ...                   ...
# 1592  2019-04-25 22:35:39
# 1593  2019-04-25 22:21:34
# 1594  2019-04-25 22:11:42
# 1595  2019-04-25 22:06:03
# 1596  2019-04-25 21:58:49
#
# [1597 rows x 8 columns]

# %% [markdown]
# <h3>ArangoDB 資料庫</h3>

# %%
db_ip='localhost'

db_conn=Connection(
    arangoURL='http://%s:8529'%db_ip,
    username='emprogria',
    password='emprogria'
)

# %%
db=db_conn['Emprogria']
db_collection=db.collections['StockInfo2']

# %% [markdown]
# <h3>資料筆數</h3>

# %%
aql='FOR doc IN StockInfo2 RETURN doc'
sub_collections=db.AQLQuery(aql, rawResults=False, batchSize=30000) #false結構化,資料子集合
print('筆數: %d' % len(sub_collections.response['result']))
# Out:
# 筆數: 3194

# %% [markdown]
# <h3>衍生欄位YM</h3>

# %%
aql='FOR doc IN StockInfo2 update {_key: doc._key,"YM" : left(doc.timestamp,8)} into StockInfo2 RETURN doc'
sub_collections=db.AQLQuery(aql, rawResults=False, batchSize=30000) #false結構化,資料子集合
queryResult=sub_collections.response['result']
_resultSet=[]
for doc in queryResult:
    _resultSet.append(doc)
DataFrame(data=_resultSet)
# Out:
#        _key               _id         _rev  \
# 0     35730  StockInfo2/35730  _dX2zW9a---
# 1     35731  StockInfo2/35731  _dX2zW9a--_
# 2     35732  StockInfo2/35732  _dX2zW9a--A
# 3     35733  StockInfo2/35733  _dX2zW9e---
# 4     35734  StockInfo2/35734  _dX2zW9e--_
# ...     ...               ...          ...
# 3189  39541  StockInfo2/39541  _dX2zXCy--p
# 3190  39542  StockInfo2/39542  _dX2zXC2---
# 3191  39543  StockInfo2/39543  _dX2zXC2--_
# 3192  39544  StockInfo2/39544  _dX2zXC2--A
# 3193  39545  StockInfo2/39545  _dX2zXC2--B
#
#                                                   title  score      id  \
# 0     Health Canada approves AstraZeneca COVID-19 va...    7.0  lt74vw
# 1     COVID-19 in Canada: 'Vaccination passports' a ...    2.0  lsh0ij
# 2     Coronavirus variants could fuel Canada's third...    6.0  lohlle
# 3     Canadian government to extend COVID-19 emergen...    1.0  lnptv8
# 4     Canada: Pfizer is 'extremely committed' to mee...    6.0  lkslm6
# ...                                                 ...    ...     ...
# 3189                                                NaN    NaN     NaN
# 3190                                                NaN    NaN     NaN
# 3191                                                NaN    NaN     NaN
# 3192                                                NaN    NaN     NaN
# 3193                                                NaN    NaN     NaN
#
#                                                     url  comms_num  \
# 0     https://www.canadaforums.ca/2021/02/health-can...        0.0
# 1     https://www.canadaforums.ca/2021/02/covid-19-i...        1.0
# 2     https://www.canadaforums.ca/2021/02/coronaviru...        0.0
# 3     https://www.canadaforums.ca/2021/02/canadian-g...        0.0
# 4     https://www.canadaforums.ca/2021/02/canada-pfi...        0.0
# ...                                                 ...        ...
# 3189                                                NaN        NaN
# 3190                                                NaN        NaN
# 3191                                                NaN        NaN
# 3192                                                NaN        NaN
# 3193                                                NaN        NaN
#
#            created            timestamp       YM body
# 0     1.614400e+09  2021-02-27 06:33:45  2021-02  NaN
# 1     1.614316e+09  2021-02-26 07:11:07  2021-02  NaN
# 2     1.613887e+09  2021-02-21 07:50:08  2021-02  NaN
# 3     1.613796e+09  2021-02-20 06:35:13  2021-02  NaN
# 4     1.613468e+09  2021-02-16 11:36:28  2021-02  NaN
# ...            ...                  ...      ...  ...
# 3189           NaN                  NaN           NaN
# 3190           NaN                  NaN           NaN
# 3191           NaN                  NaN           NaN
# 3192           NaN                  NaN           NaN
# 3193           NaN                  NaN           NaN
#
# [3194 rows x 12 columns]

# %% [markdown]
# <h3>將此資料集依照樣本時間 (timestamp) 由大到小排序</h3>

# %%
aql='FOR doc IN StockInfo2 sort doc.`timestamp` desc RETURN doc'
sub_collections=db.AQLQuery(aql, rawResults=False, batchSize=30000) #false結構化,資料子集合
queryResult=sub_collections.response['result']
_resultSet=[]
for doc in queryResult:
    _resultSet.append(doc)
DataFrame(data=_resultSet)
# Out:
#        _key               _id         _rev  \
# 0     36350  StockInfo2/36350  _dX2zypK--K
# 1     35903  StockInfo2/35903  _dX2zyom--d
# 2     36351  StockInfo2/36351  _dX2zypK--L
# 3     36352  StockInfo2/36352  _dX2zypO---
# 4     36353  StockInfo2/36353  _dX2zypO--_
# ...     ...               ...          ...
# 3189  39541  StockInfo2/39541  _dX2zyta--j
# 3190  39542  StockInfo2/39542  _dX2zyta--k
# 3191  39543  StockInfo2/39543  _dX2zyta--l
# 3192  39544  StockInfo2/39544  _dX2zyta--m
# 3193  39545  StockInfo2/39545  _dX2zyta--n
#
#                                               title  score       id  \
# 0                                           Comment    1.0  hj2gp8j
# 1     Do the covid vaccines actually prevent covid?    2.0   qky46m
# 2                                           Comment    1.0  hiywnx9
# 3                                           Comment    1.0  hiywdmg
# 4                                           Comment    1.0  hiywaa5
# ...                                             ...    ...      ...
# 3189                                            NaN    NaN      NaN
# 3190                                            NaN    NaN      NaN
# 3191                                            NaN    NaN      NaN
# 3192                                            NaN    NaN      NaN
# 3193                                            NaN    NaN      NaN
#
#       comms_num       created  \
# 0           0.0  1.635890e+09
# 1           0.0  1.635834e+09
# 2           0.0  1.635823e+09
# 3           0.0  1.635823e+09
# 4           0.0  1.635823e+09
# ...         ...           ...
# 3189        NaN           NaN
# 3190        NaN           NaN
# 3191        NaN           NaN
# 3192        NaN           NaN
# 3193        NaN           NaN
#
#                                                    body            timestamp  \
# 0     >even english\n\n"even English" Bad grammar an...  2021-11-03 00:01:38
# 1                                                   NaN  2021-11-02 08:27:23
# 2     Smart girl.  Stand up for your right to chose....  2021-11-02 05:15:32
# 3                                            It’s over!  2021-11-02 05:13:06
# 4                                             Horrible.  2021-11-02 05:12:18
# ...                                                 ...                  ...
# 3189                                                NaN                  NaN
# 3190                                                NaN                  NaN
# 3191                                                NaN                  NaN
# 3192                                                NaN                  NaN
# 3193                                                NaN                  NaN
#
#             YM                           url
# 0     2021-11-                           NaN
# 1     2021-11-  https://youtu.be/nSHlBpEgAAI
# 2     2021-11-                           NaN
# 3     2021-11-                           NaN
# 4     2021-11-                           NaN
# ...        ...                           ...
# 3189                                     NaN
# 3190                                     NaN
# 3191                                     NaN
# 3192                                     NaN
# 3193                                     NaN
#
# [3194 rows x 12 columns]

# %% [markdown]
# <h3>開啟H2資料庫</h3>

# %%
dbConnection = jaydebeapi.connect(
    "org.h2.Driver",
    "jdbc:h2:C:/Users/user/anaconda3/Projects/data/H2",
    ["SA", ""],
    "C:/Java/h2/bin/h2-1.4.200.jar")

dbCursor = dbConnection.cursor()

# %% [markdown]
# <h3>設計 SQL 語句統計各 SCORE 小計筆數</h3>

# %%
_sql=[
    "SELECT score,count(score),",
    "FROM STOCKINFO2",
]

dbCursor.execute(' '.join(_sql))
resultSet = dbCursor.fetchall()
resultSet
# Out:
# [('7', 1)]

# %% [markdown]
# <h3>關閉H2資料庫</h3>

# %%
dbCursor.close()
dbConnection.close()

# %% [markdown]
# <h3>設計 AQL 語句統計各 SCORE 小計筆數</h3>
